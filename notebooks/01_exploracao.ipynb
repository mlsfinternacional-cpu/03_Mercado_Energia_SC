# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
arquivo = "../data/raw/Municipio_Mensal_1T_2026.xlsx"

# %%
excel = pd.ExcelFile(arquivo)

# %%
excel.sheet_names
# Out:
# ['Número de UC', 'Consumo MWh']

# %%
df = pd.read_excel(arquivo, sheet_name="Consumo MWh")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df = pd.read_excel(arquivo, sheet_name="Consumo MWh")
#
# File c:\Users\User\OneDrive\Desktop\Portifolio_Data_Analytics\03_Mercado_Energia_SC\.venv\Lib\site-packages\pandas\io\excel\_base.py:494, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     488     raise ValueError(
#     489         "Engine should not be specified when passing "
#     490         "an ExcelFile - ExcelFile already has the engine set"
#     491     )
#     493 try:
# --> 494     data = io.parse(
#     495         sheet_name=sheet_name,
#     496         header=header,
#     497         names=names,
#     498         index_col=index_col,
#     499         usecols=usecols,
#     500         dtype=dtype,
#     501         converters=converters,
#     502         true_values=true_values,
#     503         false_values=false_values,
#     504         skiprows=skiprows,
#     505         nrows=nrows,
#     506         na_values=na_values,
#     507         keep_default_na=keep_default_na,
#     508         na_filter=na_filter,
#     509         verbose=verbose,
#     510         parse_dates=parse_dates,
#     511         date_format=date_format,
#     512         thousands=thousands,
#     513         decimal=decimal,
#     514         comment=comment,
#     515         skipfooter=skipfooter,
#     516         dtype_backend=dtype_backend,
#     517     )
#     518 finally:
#     519     # make sure to close opened file handles
#     520     if should_close:
#
# File c:\Users\User\OneDrive\Desktop\Portifolio_Data_Analytics\03_Mercado_Energia_SC\.venv\Lib\site-packages\pandas\io\excel\_base.py:1780, in ExcelFile.parse(self, sheet_name, header, names, index_col, usecols, converters, true_values, false_values, skiprows, nrows, na_values, parse_dates, date_format, thousands, comment, skipfooter, dtype_backend, **kwds)
#    1630 def parse(
#    1631     self,
#    1632     sheet_name: str | int | list[int] | list[str] | None = 0,
#    (...)   1649     **kwds,
#    1650 ) -> DataFrame | dict[str, DataFrame] | dict[int, DataFrame]:
#    1651     """
#    1652     Parse specified sheet(s) into a DataFrame.
#    1653
#    (...)   1778     >>> file.parse()  # doctest: +SKIP
#    1779     """
# -> 1780     return self._reader.parse(
#    1781         sheet_name=sheet_name,
#    1782         header=header,
#    1783         names=names,
#    1784         index_col=index_col,
#    1785         usecols=usecols,
#    1786         converters=converters,
#    1787         true_values=true_values,
#    1788         false_values=false_values,
#    1789         skiprows=skiprows,
#    1790         nrows=nrows,
#    1791         na_values=na_values,
#    1792         parse_dates=parse_dates,
#    1793         date_format=date_format,
#    1794         thousands=thousands,
#    1795         comment=comment,
#    1796         skipfooter=skipfooter,
#    1797         dtype_backend=dtype_backend,
#    1798         **kwds,
#    1799     )
#
# File c:\Users\User\OneDrive\Desktop\Portifolio_Data_Analytics\03_Mercado_Energia_SC\.venv\Lib\site-packages\pandas\io\excel\_base.py:758, in BaseExcelReader.parse(self, sheet_name, header, names, index_col, usecols, dtype, true_values, false_values, skiprows, nrows, na_values, verbose, parse_dates, date_format, thousands, decimal, comment, skipfooter, dtype_backend, **kwds)
#     755     sheet = self.get_sheet_by_index(asheetname)
#     757 file_rows_needed = self._calc_rows(header, index_col, skiprows, nrows)
# --> 758 data = self.get_sheet_data(sheet, file_rows_needed)
#     759 if hasattr(sheet, "close"):
#     760     # pyxlsb opens two TemporaryFiles
#     761     sheet.close()
#
# File c:\Users\User\OneDrive\Desktop\Portifolio_Data_Analytics\03_Mercado_Energia_SC\.venv\Lib\site-packages\pandas\io\excel\_openpyxl.py:623, in OpenpyxlReader.get_sheet_data(self, sheet, file_rows_needed)
#     621 last_row_with_data = -1
#     622 for row_number, row in enumerate(sheet.rows):
# --> 623     converted_row = [self._convert_cell(cell) for cell in row]
#     624     while converted_row and converted_row[-1] == "":
#     625         # trim trailing empty elements
#     626         converted_row.pop()
#
# File c:\Users\User\OneDrive\Desktop\Portifolio_Data_Analytics\03_Mercado_Energia_SC\.venv\Lib\site-packages\pandas\io\excel\_openpyxl.py:596, in OpenpyxlReader._convert_cell(self, cell)
#     593     self.raise_if_bad_sheet_by_index(index)
#     594     return self.book.worksheets[index]
# --> 596 def _convert_cell(self, cell) -> Scalar:
#     597     from openpyxl.cell.cell import (
#     598         TYPE_ERROR,
#     599         TYPE_NUMERIC,
#     600     )
#     602     if cell.value is None:
#
# KeyboardInterrupt:

# %%
df.head()
# Out:
#      tipo  cod_muni agência                 núcleo               unidade  \
# 0  Cativo      1101   ARFLO  Núcleo Grande Capital  Florianópolis (sede)
# 1  Cativo      1101   ARFLO  Núcleo Grande Capital  Florianópolis (sede)
# 2  Cativo      1101   ARFLO  Núcleo Grande Capital  Florianópolis (sede)
# 3  Cativo      1101   ARFLO  Núcleo Grande Capital  Florianópolis (sede)
# 4  Cativo      1101   ARFLO  Núcleo Grande Capital  Florianópolis (sede)
#
#        município  cod_classe         classe  1994-01-01 00:00:00  \
# 0  Florianópolis           1    Residencial            21357.147
# 1  Florianópolis           2     Industrial             1698.383
# 2  Florianópolis           3      Comercial            14766.175
# 3  Florianópolis           4          Rural               25.908
# 4  Florianópolis           5  Poder Público             6393.112
#
#    1994-02-01 00:00:00  ...  2025-06-01 00:00:00  2025-07-01 00:00:00  \
# 0            20782.785  ...         52878.556648         60441.735810
# 1             1641.103  ...          2558.042630          2877.644839
# 2            13420.879  ...         24422.064633         22060.793725
# 3               23.863  ...            37.052000            43.193000
# 4             4903.650  ...          6667.282925          7209.118309
#
#    2025-08-01 00:00:00  2025-09-01 00:00:00  2025-10-01 00:00:00  \
# 0         54284.838228         58371.440918         53787.994558
# 1          2557.793542          2761.337071          2972.536314
# 2         23029.908608         23087.512572         22567.306346
# 3            29.520000            37.073000               37.665
# 4          6673.288946          6409.265993          6528.080709
#
#    2025-11-01 00:00:00  2025-12-01 00:00:00  2026-01-01 00:00:00  \
# 0         53800.328053         56821.529842         87456.494352
# 1          2669.177959          2677.598859          3332.905398
# 2         22916.987372         24222.198117         30172.991984
# 3            38.949800            43.244000            50.350000
# 4          7015.699795          6543.715033          7558.026813
#
#    2026-02-01 00:00:00  2026-03-01 00:00:00
# 0         86524.998202         83895.217345
# 1          3222.091413          3746.075399
# 2         32276.237126         35388.860964
# 3            33.971450            42.984200
# 4          8207.902689          8857.708610
#
# [5 rows x 395 columns]

# %%
df.shape
# Out:
# (7716, 395)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7716 entries, 0 to 7715
# Columns: 395 entries, tipo to 2026-03-01 00:00:00
# dtypes: float64(386), int64(2), object(1), str(6)
# memory usage: 23.3+ MB

# %%
df.tail(5)
# Out:
#        tipo  cod_muni agência        núcleo                   unidade  \
# 7711  Livre     17109   ARITA  Núcleo Leste             Itajaí (sede)
# 7712  Livre      3101   ARJOI  Núcleo Norte          Joinville (sede)
# 7713  Livre     17108   ARITA  Núcleo Leste             Itajaí (sede)
# 7714  Livre     17110   ARITA  Núcleo Leste             Itajaí (sede)
# 7715  Livre      7101   ARJSL  Núcleo Norte  Jaraguá do Sul (unidade)
#
#            município  cod_classe      classe  1994-01-01 00:00:00  \
# 7711        Piçarras           2  Industrial                  NaN
# 7712       Joinville           2  Industrial                  NaN
# 7713     Barra Velha           2  Industrial                  NaN
# 7714           Penha           2  Industrial                  NaN
# 7715  Jaraguá do Sul           2  Industrial                  NaN
#
#       1994-02-01 00:00:00  ...  2025-06-01 00:00:00  2025-07-01 00:00:00  \
# 7711                  NaN  ...                  NaN                  NaN
# 7712                  NaN  ...                  NaN                  NaN
# 7713                  NaN  ...                  NaN                  NaN
# 7714                  NaN  ...                  NaN                  NaN
# 7715                  NaN  ...                  NaN                  NaN
#
#       2025-08-01 00:00:00  2025-09-01 00:00:00  2025-10-01 00:00:00  \
# 7711                  NaN                  NaN                  NaN
# 7712                  NaN                  NaN                  NaN
# 7713                  NaN                  NaN                  NaN
# 7714                  NaN                  NaN                  NaN
# 7715                  NaN                  NaN                  NaN
#
#       2025-11-01 00:00:00  2025-12-01 00:00:00  2026-01-01 00:00:00  \
# 7711                  NaN                  NaN                  NaN
# 7712                  NaN                  NaN                  NaN
# 7713                  NaN                  NaN                  NaN
# 7714                  NaN                  NaN                  NaN
# 7715                  NaN                  NaN                  NaN
#
#       2026-02-01 00:00:00  2026-03-01 00:00:00
# 7711                  NaN            11.876050
# 7712                  NaN             5.477670
# 7713                  NaN             5.091900
# 7714                  NaN             9.759996
# 7715                  NaN            12.607623
#
# [5 rows x 395 columns]

# %%
df.columns
# Out:
# Index([             'tipo',          'cod_muni',           'agência',
#                   'núcleo',           'unidade',         'município',
#               'cod_classe',            'classe', 1994-01-01 00:00:00,
#        1994-02-01 00:00:00,
#        ...
#        2025-06-01 00:00:00, 2025-07-01 00:00:00, 2025-08-01 00:00:00,
#        2025-09-01 00:00:00, 2025-10-01 00:00:00, 2025-11-01 00:00:00,
#        2025-12-01 00:00:00, 2026-01-01 00:00:00, 2026-02-01 00:00:00,
#        2026-03-01 00:00:00],
#       dtype='object', length=395)

# %%
df["município"].nunique()
# Out:
# 290

# %%
df["município"].unique()
# Out:
# <StringArray>
# [            'Florianópolis',                  'São José',
#                    'Palhoça', 'Santo Amaro da Imperatriz',
#               'Águas Mornas',                   'Biguaçu',
#             'Antônio Carlos',    'Governador Celso Ramos',
#                    'Tijucas',                 'Canelinha',
#  ...
#                 'Sul Brasil',            'Lageado Grande',
#               'Jardinópolis',                     'Irati',
#                     'Ipuaçu',               'Águas Frias',
#            'Santiago do Sul',                     'Jupiá',
#                  'Bom Jesus',        'Bom Jesus do Oeste']
# Length: 290, dtype: str
